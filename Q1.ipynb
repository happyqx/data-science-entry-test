# %%
import numbers

# %%
def swap(x, y):
    """
    Task 1
    - Create a function that would swap the value of x and y using only x and y as variables.
    - x and y must be numeric.
    - Return -1 if x and y is not numeric, and
    - print the swapped values if both x and y are numeric.
    """
    if not (isinstance(x, numbers.Number) and isinstance(y, numbers.Number)):
        return -1
    
    x, y = y, x # Swap using tuple unpacking

    print(f"Swapped values: x = {x}, y = {y}")

# %%
# Task 2
# Invoke the function "swap" using the following scenarios:
# - "Apple", 10
swap("Apple", 10)  # This should return -1
# Out:
# -1

# %%
# - 9, 17
swap(9, 17)  # This should print the swapped values
# Out:
# Swapped values: x = 17, y = 9
